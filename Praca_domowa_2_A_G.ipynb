# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexsydfq/eo/blob/main/Praca_domowa_2_A_G.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %% [markdown]
# **Simple visualization and classification of the digits dataset**
# =============================================================
#
# Do a simple MLP classification of 28x28 MNIST dataset
#
# *Marcin Wolter*

# %%
#import packages and load datasets

import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.model_selection import train_test_split


# Load data from https://www.openml.org/d/554
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
X = X / 255.


# split the data into training and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33, train_size=0.5)

print("Image shape: ",X_train.shape)
# dimension of face image
# Out:
# Image shape:  (35000, 784)

# %% [markdown]
# Plot the data: images of digits
# -------------------------------
#
# Each data in a 28x28 image
#
# ![digits_1.png](data:image/png;base64,...)

# %%
# leave empty for time beeing

# %% [markdown]
# ## **Classify with MLP**

# %%
# tu musimy zdefiniować klasyfikator, wytrenowaći sprawdzić "score" dla 
# danych testowych
#Proponowane parametry sieci: ukryte warstwy [100,100],solver adam, verbose=10 

from matplotlib import pyplot as plt

# %%
clf = MLPClassifier(hidden_layer_sizes=(100,100), activation='relu', alpha=0.001, 
                    learning_rate_init=0.001, early_stopping=True,validation_fraction=0.2,solver='adam',verbose=10,n_iter_no_change=100,max_iter=1000)
                    #max_iter=1000) 


print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# get prediction
Z = clf.predict_proba(X_test)[:,1] # returns probability 
print(Z)
# Out:
# Iteration 1, loss = 0.58072381
# Validation score: 0.920429
# Iteration 2, loss = 0.22472208
# Validation score: 0.935714
# Iteration 3, loss = 0.16439557
# Validation score: 0.947429
# Iteration 4, loss = 0.13005289
# Validation score: 0.952143
# Iteration 5, loss = 0.10487254
# Validation score: 0.957143
# Iteration 6, loss = 0.09106513
# Validation score: 0.953857
# Iteration 7, loss = 0.07222982
# Validation score: 0.957286
# Iteration 8, loss = 0.06147609
# Validation score: 0.962429
# Iteration 9, loss = 0.05019701
# Validation score: 0.958286
# Iteration 10, loss = 0.04296633
# Validation score: 0.963000
# Iteration 11, loss = 0.03758393
# Validation score: 0.964571
# Iteration 12, loss = 0.03219373
# Validation score: 0.964000
# Iteration 13, loss = 0.02676514
# Validation score: 0.963714
# Iteration 14, loss = 0.02186434
# Validation score: 0.965143
# Iteration 15, loss = 0.01914151
# Validation score: 0.966000
# Iteration 16, loss = 0.01591827
# Validation score: 0.965000
# Iteration 17, loss = 0.01267687
# Validation score: 0.965857
# Iteration 18, loss = 0.01196852
# Validation score: 0.966571
# Iteration 19, loss = 0.00976199
# Validation score: 0.966857
# Iteration 20, loss = 0.00808221
# Validation score: 0.966857
# Iteration 21, loss = 0.00772261
# Validation score: 0.967286
# Iteration 22, loss = 0.00704645
# Validation score: 0.965000
# Iteration 23, loss = 0.01010875
# Validation score: 0.966000
# Iteration 24, loss = 0.01000744
# Validation score: 0.963143
# Iteration 25, loss = 0.00991686
# Validation score: 0.965143
# Iteration 26, loss = 0.00961683
# Validation score: 0.964429
# Iteration 27, loss = 0.00564341
# Validation score: 0.968286
# Iteration 28, loss = 0.00350369
# Validation score: 0.970000
# Iteration 29, loss = 0.00317130
# Validation score: 0.969286
# Iteration 30, loss = 0.00293223
# Validation score: 0.969143
# Iteration 31, loss = 0.00303333
# Validation score: 0.969571
# Iteration 32, loss = 0.00275399
# Validation score: 0.968714
# Iteration 33, loss = 0.00267341
# Validation score: 0.969143
# Iteration 34, loss = 0.00256905
# Validation score: 0.969143
# Iteration 35, loss = 0.00248004
# Validation score: 0.969429
# Iteration 36, loss = 0.00245680
# Validation score: 0.968857
# Iteration 37, loss = 0.00242165
# Validation score: 0.968857
# Iteration 38, loss = 0.00235046
# Validation score: 0.968571
# Iteration 39, loss = 0.00230328
# Validation score: 0.968286
# Iteration 40, loss = 0.00226637
# Validation score: 0.969143
# Iteration 41, loss = 0.00222759
# Validation score: 0.968571
# Iteration 42, loss = 0.00220294
# Validation score: 0.969286
# Iteration 43, loss = 0.00216458
# Validation score: 0.969000
# Iteration 44, loss = 0.00215783
# Validation score: 0.969143
# Iteration 45, loss = 0.00211771
# Validation score: 0.969429
# Iteration 46, loss = 0.00208630
# Validation score: 0.968714
# Iteration 47, loss = 0.00208909
# Validation score: 0.968571
# Iteration 48, loss = 0.00204502
# Validation score: 0.968143
# Iteration 49, loss = 0.00202435
# Validation score: 0.969000
# Iteration 50, loss = 0.00200792
# Validation score: 0.968857
# Iteration 51, loss = 0.00199598
# Validation score: 0.968571
# Iteration 52, loss = 0.00198269
# Validation score: 0.969571
# Iteration 53, loss = 0.00193569
# Validation score: 0.968286
# Iteration 54, loss = 0.00192587
# Validation score: 0.968143
# Iteration 55, loss = 0.07281085
# Validation score: 0.960286
# Iteration 56, loss = 0.02447580
# Validation score: 0.967857
# Iteration 57, loss = 0.00652290
# Validation score: 0.967286
# Iteration 58, loss = 0.00363308
# Validation score: 0.968857
# Iteration 59, loss = 0.00276093
# Validation score: 0.969714
# Iteration 60, loss = 0.00257803
# Validation score: 0.969571
# Iteration 61, loss = 0.00249806
# Validation score: 0.969571
# Iteration 62, loss = 0.00244079
# Validation score: 0.969857
# Iteration 63, loss = 0.00238873
# Validation score: 0.969714
# Iteration 64, loss = 0.00234973
# Validation score: 0.970143
# Iteration 65, loss = 0.00231638
# Validation score: 0.970429
# Iteration 66, loss = 0.00228789
# Validation score: 0.970714
# Iteration 67, loss = 0.00225681
# Validation score: 0.970000
# Iteration 68, loss = 0.00223509
# Validation score: 0.970143
# Iteration 69, loss = 0.00221096
# Validation score: 0.970714
# Iteration 70, loss = 0.00218962
# Validation score: 0.970571
# Iteration 71, loss = 0.00217015
# Validation score: 0.970429
# Iteration 72, loss = 0.00215090
# Validation score: 0.970000
# Iteration 73, loss = 0.00213183
# Validation score: 0.970143
# Iteration 74, loss = 0.00211434
# Validation score: 0.970286
# Iteration 75, loss = 0.00209603
# Validation score: 0.970000
# Iteration 76, loss = 0.00207988
# Validation score: 0.969857
# Iteration 77, loss = 0.00206329
# Validation score: 0.969857
# Iteration 78, loss = 0.00204520
# Validation score: 0.969857
# Iteration 79, loss = 0.00202839
# Validation score: 0.969571
# Iteration 80, loss = 0.00201142
# Validation score: 0.969857
# Iteration 81, loss = 0.00199409
# Validation score: 0.969857
# Iteration 82, loss = 0.00197775
# Validation score: 0.969143
# Iteration 83, loss = 0.00196201
# Validation score: 0.970000
# Iteration 84, loss = 0.00195377
# Validation score: 0.969857
# Iteration 85, loss = 0.00192644
# Validation score: 0.969714
# Iteration 86, loss = 0.00190697
# Validation score: 0.969571
# Iteration 87, loss = 0.00189134
# Validation score: 0.969714
# Iteration 88, loss = 0.00187410
# Validation score: 0.970143
# Iteration 89, loss = 0.00185768
# Validation score: 0.970143
# Iteration 90, loss = 0.00183638
# Validation score: 0.970286
# Iteration 91, loss = 0.00183021
# Validation score: 0.970000
# Iteration 92, loss = 0.00181315
# Validation score: 0.969429
# Iteration 93, loss = 0.00179332
# Validation score: 0.970714
# Iteration 94, loss = 0.00177521
# Validation score: 0.969571
# Iteration 95, loss = 0.00175074
# Validation score: 0.969429
# Iteration 96, loss = 0.05412331
# Validation score: 0.959714
# Iteration 97, loss = 0.01920502
# Validation score: 0.966571
# Iteration 98, loss = 0.00724542
# Validation score: 0.969857
# Iteration 99, loss = 0.00427206
# Validation score: 0.970429
# Iteration 100, loss = 0.00259938
# Validation score: 0.971429
# Iteration 101, loss = 0.00232076
# Validation score: 0.971429
# Iteration 102, loss = 0.00224687
# Validation score: 0.970571
# Iteration 103, loss = 0.00220320
# Validation score: 0.970714
# Iteration 104, loss = 0.00217113
# Validation score: 0.970714
# Iteration 105, loss = 0.00214363
# Validation score: 0.971000
# Iteration 106, loss = 0.00212195
# Validation score: 0.972000
# Iteration 107, loss = 0.00210237
# Validation score: 0.971143
# Iteration 108, loss = 0.00208330
# Validation score: 0.970857
# Iteration 109, loss = 0.00206658
# Validation score: 0.970857
# Iteration 110, loss = 0.00205012
# Validation score: 0.970857
# Iteration 111, loss = 0.00203619
# Validation score: 0.971000
# Iteration 112, loss = 0.00202071
# Validation score: 0.971000
# Iteration 113, loss = 0.00200675
# Validation score: 0.971143
# Iteration 114, loss = 0.00199080
# Validation score: 0.971143
# Iteration 115, loss = 0.00197803
# Validation score: 0.971143
# Iteration 116, loss = 0.00196458
# Validation score: 0.971714
# Iteration 117, loss = 0.00195044
# Validation score: 0.971429
# Iteration 118, loss = 0.00193695
# Validation score: 0.972000
# Iteration 119, loss = 0.00192368
# Validation score: 0.971143
# Iteration 120, loss = 0.00190806
# Validation score: 0.971429
# Iteration 121, loss = 0.00189517
# Validation score: 0.970571
# Iteration 122, loss = 0.00187986
# Validation score: 0.972000
# Iteration 123, loss = 0.00186517
# Validation score: 0.971571
# Iteration 124, loss = 0.00185091
# Validation score: 0.971286
# Iteration 125, loss = 0.00183596
# Validation score: 0.970857
# Iteration 126, loss = 0.00181912
# Validation score: 0.971286
# Iteration 127, loss = 0.00180424
# Validation score: 0.970857
# Iteration 128, loss = 0.00178701
# Validation score: 0.971571
# Iteration 129, loss = 0.00177151
# Validation score: 0.971286
# Iteration 130, loss = 0.00175798
# Validation score: 0.971286
# Iteration 131, loss = 0.00173881
# Validation score: 0.970857
# Iteration 132, loss = 0.00172215
# Validation score: 0.970286
# Iteration 133, loss = 0.00170512
# Validation score: 0.971143
# Iteration 134, loss = 0.00169288
# Validation score: 0.970714
# Iteration 135, loss = 0.00167069
# Validation score: 0.970857
# Iteration 136, loss = 0.00165867
# Validation score: 0.970857
# Iteration 137, loss = 0.03851779
# Validation score: 0.958429
# Iteration 138, loss = 0.02412128
# Validation score: 0.965571
# Iteration 139, loss = 0.00994373
# Validation score: 0.970000
# Iteration 140, loss = 0.00415091
# Validation score: 0.970571
# Iteration 141, loss = 0.00252064
# Validation score: 0.971286
# Iteration 142, loss = 0.00221781
# Validation score: 0.972000
# Iteration 143, loss = 0.00211535
# Validation score: 0.972571
# Iteration 144, loss = 0.00207663
# Validation score: 0.973000
# Iteration 145, loss = 0.00205012
# Validation score: 0.972429
# Iteration 146, loss = 0.00202668
# Validation score: 0.972571
# Iteration 147, loss = 0.00200748
# Validation score: 0.972429
# Iteration 148, loss = 0.00199059
# Validation score: 0.972571
# Iteration 149, loss = 0.00197363
# Validation score: 0.972571
# Iteration 150, loss = 0.00195960
# Validation score: 0.972714
# Iteration 151, loss = 0.00194447
# Validation score: 0.972571
# Iteration 152, loss = 0.00193056
# Validation score: 0.972714
# Iteration 153, loss = 0.00191863
# Validation score: 0.972857
# Iteration 154, loss = 0.00190505
# Validation score: 0.973286
# Iteration 155, loss = 0.00189177
# Validation score: 0.972429
# Iteration 156, loss = 0.00187963
# Validation score: 0.973143
# Iteration 157, loss = 0.00186754
# Validation score: 0.972429
# Iteration 158, loss = 0.00185412
# Validation score: 0.972857
# Iteration 159, loss = 0.00184170
# Validation score: 0.973143
# Iteration 160, loss = 0.00182858
# Validation score: 0.973000
# Iteration 161, loss = 0.00181659
# Validation score: 0.973286
# Iteration 162, loss = 0.00180313
# Validation score: 0.972857
# Iteration 163, loss = 0.00178946
# Validation score: 0.972857
# Iteration 164, loss = 0.00177607
# Validation score: 0.972571
# Iteration 165, loss = 0.00176212
# Validation score: 0.972286
# Iteration 166, loss = 0.00174792
# Validation score: 0.972000
# Iteration 167, loss = 0.00173321
# Validation score: 0.972143
# Iteration 168, loss = 0.00171975
# Validation score: 0.972000
# Iteration 169, loss = 0.00170377
# Validation score: 0.972143
# Iteration 170, loss = 0.00168856
# Validation score: 0.972143
# Iteration 171, loss = 0.00167464
# Validation score: 0.971714
# Iteration 172, loss = 0.00165893
# Validation score: 0.972286
# Iteration 173, loss = 0.00164272
# Validation score: 0.972714
# Iteration 174, loss = 0.00162771
# Validation score: 0.972429
# Iteration 175, loss = 0.00161048
# Validation score: 0.972286
# Iteration 176, loss = 0.00159882
# Validation score: 0.972000
# Iteration 177, loss = 0.00158358
# Validation score: 0.971286
# Iteration 178, loss = 0.00157317
# Validation score: 0.971000
# Iteration 179, loss = 0.02180145
# Validation score: 0.953857
# Iteration 180, loss = 0.03681822
# Validation score: 0.958714
# Iteration 181, loss = 0.01164332
# Validation score: 0.967857
# Iteration 182, loss = 0.00425076
# Validation score: 0.970429
# Iteration 183, loss = 0.00249827
# Validation score: 0.971571
# Iteration 184, loss = 0.00212572
# Validation score: 0.972000
# Iteration 185, loss = 0.00205393
# Validation score: 0.972571
# Iteration 186, loss = 0.00200995
# Validation score: 0.972286
# Iteration 187, loss = 0.00197964
# Validation score: 0.972143
# Iteration 188, loss = 0.00195425
# Validation score: 0.972143
# Iteration 189, loss = 0.00193308
# Validation score: 0.972143
# Iteration 190, loss = 0.00191318
# Validation score: 0.971571
# Iteration 191, loss = 0.00189762
# Validation score: 0.972000
# Iteration 192, loss = 0.00188189
# Validation score: 0.971714
# Iteration 193, loss = 0.00186566
# Validation score: 0.971714
# Iteration 194, loss = 0.00185319
# Validation score: 0.971429
# Iteration 195, loss = 0.00183841
# Validation score: 0.971143
# Iteration 196, loss = 0.00182604
# Validation score: 0.970714
# Iteration 197, loss = 0.00181355
# Validation score: 0.970857
# Iteration 198, loss = 0.00180160
# Validation score: 0.970571
# Iteration 199, loss = 0.00178876
# Validation score: 0.970714
# Iteration 200, loss = 0.00177679
# Validation score: 0.970714
# Iteration 201, loss = 0.00176430
# Validation score: 0.971000
# Iteration 202, loss = 0.00175200
# Validation score: 0.971000
# Iteration 203, loss = 0.00173866
# Validation score: 0.971000
# Iteration 204, loss = 0.00172667
# Validation score: 0.971000
# Iteration 205, loss = 0.00171383
# Validation score: 0.971286
# Iteration 206, loss = 0.00170148
# Validation score: 0.971000
# Iteration 207, loss = 0.00168870
# Validation score: 0.971143
# Iteration 208, loss = 0.00167459
# Validation score: 0.971000
# Iteration 209, loss = 0.00166186
# Validation score: 0.970857
# Iteration 210, loss = 0.00164811
# Validation score: 0.971857
# Iteration 211, loss = 0.00163501
# Validation score: 0.971571
# Iteration 212, loss = 0.00162145
# Validation score: 0.971286
# Iteration 213, loss = 0.00160863
# Validation score: 0.971857
# Iteration 214, loss = 0.00159312
# Validation score: 0.971429
# Iteration 215, loss = 0.00157850
# Validation score: 0.971286
# Iteration 216, loss = 0.00156423
# Validation score: 0.971286
# Iteration 217, loss = 0.00155199
# Validation score: 0.971571
# Iteration 218, loss = 0.00153828
# Validation score: 0.972000
# Iteration 219, loss = 0.00152549
# Validation score: 0.972286
# Iteration 220, loss = 0.00150961
# Validation score: 0.971571
# Iteration 221, loss = 0.00150317
# Validation score: 0.970857
# Iteration 222, loss = 0.00148539
# Validation score: 0.971857
# Iteration 223, loss = 0.04106106
# Validation score: 0.962286
# Iteration 224, loss = 0.01929763
# Validation score: 0.968286
# Iteration 225, loss = 0.00687415
# Validation score: 0.970571
# Iteration 226, loss = 0.00279865
# Validation score: 0.970000
# Iteration 227, loss = 0.00233918
# Validation score: 0.972286
# Iteration 228, loss = 0.00201590
# Validation score: 0.971000
# Iteration 229, loss = 0.00195266
# Validation score: 0.971714
# Iteration 230, loss = 0.00191243
# Validation score: 0.971286
# Iteration 231, loss = 0.00188382
# Validation score: 0.971143
# Iteration 232, loss = 0.00185896
# Validation score: 0.971714
# Iteration 233, loss = 0.00183692
# Validation score: 0.971571
# Iteration 234, loss = 0.00180726
# Validation score: 0.972429
# Iteration 235, loss = 0.00178601
# Validation score: 0.972286
# Iteration 236, loss = 0.00176930
# Validation score: 0.972429
# Iteration 237, loss = 0.00175345
# Validation score: 0.972429
# Iteration 238, loss = 0.00174241
# Validation score: 0.972143
# Iteration 239, loss = 0.00172986
# Validation score: 0.972143
# Iteration 240, loss = 0.00171793
# Validation score: 0.972429
# Iteration 241, loss = 0.00170751
# Validation score: 0.972143
# Iteration 242, loss = 0.00169630
# Validation score: 0.972143
# Iteration 243, loss = 0.00168587
# Validation score: 0.972429
# Iteration 244, loss = 0.00167401
# Validation score: 0.973286
# Iteration 245, loss = 0.00166319
# Validation score: 0.972429
# Iteration 246, loss = 0.00165250
# Validation score: 0.972714
# Iteration 247, loss = 0.00164103
# Validation score: 0.972143
# Iteration 248, loss = 0.00163044
# Validation score: 0.972286
# Iteration 249, loss = 0.00161889
# Validation score: 0.972714
# Iteration 250, loss = 0.00160867
# Validation score: 0.972714
# Iteration 251, loss = 0.00159558
# Validation score: 0.972286
# Iteration 252, loss = 0.00158287
# Validation score: 0.972571
# Iteration 253, loss = 0.00157154
# Validation score: 0.972429
# Iteration 254, loss = 0.00155923
# Validation score: 0.972429
# Iteration 255, loss = 0.00154655
# Validation score: 0.972429
# Validation score did not improve more than tol=0.000100 for 100 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=0.001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(100, 100), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=100, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=10,
#               warm_start=False)
# Score =  0.9726285714285714
# [1.82537029e-13 9.99999999e-01 1.48281323e-19 ... 9.19208577e-12
#  5.54849189e-18 1.00000000e+00]

# %% [markdown]
# # **Plot loss**
# ![loss_1.png](data:image/png;base64,...)

# %%
# tu rysujemy loss i validation score
# zostawiamy na razie puste

# %% [markdown]
# #**Plot results**
# ![digits_2.png](data:image/png;base64,...)

# %%
# Plot the prediction
fig = plt.figure(figsize=(12, 12))
predicted = clf.predict(X_test)

for i in range(64):
  ax = fig.add_subplot(8, 8, i + 1)
  ax.imshow(X_test[i].reshape(28,28),cmap=plt.cm.binary)
  if y_test[i]== predicted[i]:
    ax.text(0,6,predicted[i] + ' ' + y_test[i], color='blue')
  else:
    ax.text(0,6,predicted[i] + ' ' + y_test[i], color='red')
# Tu rysujemy cyfry z wynikami
# na razie zostawiamy puste

# %% [markdown]
# Print the classification report

# %%
#from sklearn import metrics
#print(metrics.classification_report(expected, predicted))

# %% [markdown]
# # **Print the confusion matrix (expected true label vs. the reconstructed label)**

# %%
#print(metrics.confusion_matrix(expected, predicted))

# %% [markdown]
# # **Repeat the same classification for faces**

# %%
####################################################
# Load dataset with faces
from sklearn.datasets import fetch_lfw_people

# #############################################################################
# Download the data, if not already on disk and load it as numpy arrays

lfw_people = fetch_lfw_people(min_faces_per_person=100, resize=0.50)  
print(lfw_people.images.shape)


# introspect the images arrays to find the shapes (for plotting)
n_samples, h, w = lfw_people.images.shape

# for machine learning we use the 2 data directly (as relative pixel
# positions info is ignored by this model)
X = lfw_people.data
n_features = X.shape[1]

# the label to predict is the id of the person
y = lfw_people.target
# to get real names, not digits
target_names = lfw_people.target_names

# split into a training and testing set
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

print("Image shape: ",X_train.shape)
# dimension of face image
nfaces, h, w = lfw_people.images.shape
print("Image shape: ", h, w)
# Out:
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976012
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976009
# Downloading LFW metadata: https://ndownloader.figshare.com/files/5976006
# Downloading LFW data (~200MB): https://ndownloader.figshare.com/files/5976015
# (1140, 62, 47)
# Image shape:  (855, 2914)
# Image shape:  62 47

# %% [markdown]
# Plot the data: images of faces
# -------------------------------
#
# Each data in a 32x24 image
#
# ![faces_1.png](data:image/png;base64,...)

# %%
# tu rysujemy twarze
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(16, 16)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(100):
  ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
  ax.imshow(X_test[i].reshape(h,w), cmap=plt.cm.gray, interpolation='nearest')
  # label the image with the target value
  ax.text(0, 7, str(target_names[y_test[i]]))

# %% [markdown]
# ## **Classify with MLP**

# %%
# train the model
clf = MLPClassifier(hidden_layer_sizes=(100,100), activation='relu', alpha=1,
                    learning_rate_init=0.001, early_stopping=True,validation_fraction=0.2,solver='adam',verbose=10,n_iter_no_change=90,max_iter=1000)
                    #max_iter=1000) 


print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# get prediction
Z = clf.predict_proba(X_test)[:,1] # returns probability 
print(Z)
# Out:
# Iteration 1, loss = inf
# Validation score: 0.076023
# Iteration 2, loss = inf
# Validation score: 0.374269
# Iteration 3, loss = 160.36417209
# Validation score: 0.520468
# Iteration 4, loss = 137.27298108
# Validation score: 0.076023
# Iteration 5, loss = 106.20223090
# Validation score: 0.520468
# Iteration 6, loss = 166.08295752
# Validation score: 0.081871
# Iteration 7, loss = 150.10448038
# Validation score: 0.111111
# Iteration 8, loss = 99.38925589
# Validation score: 0.520468
# Iteration 9, loss = 75.88174964
# Validation score: 0.152047
# Iteration 10, loss = 71.61557490
# Validation score: 0.526316
# Iteration 11, loss = 48.46478858
# Validation score: 0.473684
# Iteration 12, loss = 38.37586213
# Validation score: 0.415205
# Iteration 13, loss = 32.24806152
# Validation score: 0.549708
# Iteration 14, loss = 24.06485836
# Validation score: 0.157895
# Iteration 15, loss = 26.51320236
# Validation score: 0.549708
# Iteration 16, loss = 14.76485590
# Validation score: 0.502924
# Iteration 17, loss = 11.75252107
# Validation score: 0.555556
# Iteration 18, loss = 8.73300260
# Validation score: 0.625731
# Iteration 19, loss = 10.05733929
# Validation score: 0.543860
# Iteration 20, loss = 10.76633987
# Validation score: 0.461988
# Iteration 21, loss = 9.94156582
# Validation score: 0.543860
# Iteration 22, loss = 6.62587062
# Validation score: 0.543860
# Iteration 23, loss = 7.10525166
# Validation score: 0.625731
# Iteration 24, loss = 5.86110909
# Validation score: 0.625731
# Iteration 25, loss = 6.32404381
# Validation score: 0.631579
# Iteration 26, loss = 8.78807885
# Validation score: 0.614035
# Iteration 27, loss = 8.99559080
# Validation score: 0.631579
# Iteration 28, loss = 7.25284298
# Validation score: 0.561404
# Iteration 29, loss = 11.03763693
# Validation score: 0.573099
# Iteration 30, loss = 7.92193539
# Validation score: 0.643275
# Iteration 31, loss = 7.20223088
# Validation score: 0.684211
# Iteration 32, loss = 7.95589935
# Validation score: 0.643275
# Iteration 33, loss = 9.73593070
# Validation score: 0.491228
# Iteration 34, loss = 7.72779843
# Validation score: 0.479532
# Iteration 35, loss = 8.53384332
# Validation score: 0.619883
# Iteration 36, loss = 6.31085644
# Validation score: 0.707602
# Iteration 37, loss = 6.72194058
# Validation score: 0.573099
# Iteration 38, loss = 5.11715172
# Validation score: 0.649123
# Iteration 39, loss = 4.48918009
# Validation score: 0.713450
# Iteration 40, loss = 5.63122623
# Validation score: 0.614035
# Iteration 41, loss = 6.29972648
# Validation score: 0.473684
# Iteration 42, loss = 10.99040466
# Validation score: 0.608187
# Iteration 43, loss = 14.52202184
# Validation score: 0.362573
# Iteration 44, loss = 26.16903732
# Validation score: 0.140351
# Iteration 45, loss = 28.53469732
# Validation score: 0.385965
# Iteration 46, loss = 42.73364129
# Validation score: 0.350877
# Iteration 47, loss = 26.38081205
# Validation score: 0.485380
# Iteration 48, loss = 31.81425212
# Validation score: 0.584795
# Iteration 49, loss = 18.44642189
# Validation score: 0.619883
# Iteration 50, loss = 16.14731787
# Validation score: 0.625731
# Iteration 51, loss = 11.23139285
# Validation score: 0.672515
# Iteration 52, loss = 8.72299093
# Validation score: 0.625731
# Iteration 53, loss = 7.04981965
# Validation score: 0.695906
# Iteration 54, loss = 5.71213480
# Validation score: 0.695906
# Iteration 55, loss = 5.21784960
# Validation score: 0.660819
# Iteration 56, loss = 3.77992999
# Validation score: 0.730994
# Iteration 57, loss = 2.88534802
# Validation score: 0.760234
# Iteration 58, loss = 2.90943728
# Validation score: 0.742690
# Iteration 59, loss = 2.94276741
# Validation score: 0.725146
# Iteration 60, loss = 3.13907861
# Validation score: 0.730994
# Iteration 61, loss = 3.35720324
# Validation score: 0.754386
# Iteration 62, loss = 3.53335658
# Validation score: 0.771930
# Iteration 63, loss = 3.93404819
# Validation score: 0.748538
# Iteration 64, loss = 5.57676973
# Validation score: 0.748538
# Iteration 65, loss = 4.83393653
# Validation score: 0.713450
# Iteration 66, loss = 4.05048822
# Validation score: 0.707602
# Iteration 67, loss = 2.66896150
# Validation score: 0.725146
# Iteration 68, loss = 2.45937862
# Validation score: 0.695906
# Iteration 69, loss = 2.50333262
# Validation score: 0.760234
# Iteration 70, loss = 2.60578142
# Validation score: 0.754386
# Iteration 71, loss = 2.22932663
# Validation score: 0.730994
# Iteration 72, loss = 2.30803517
# Validation score: 0.736842
# Iteration 73, loss = 1.89963757
# Validation score: 0.754386
# Iteration 74, loss = 1.57358705
# Validation score: 0.730994
# Iteration 75, loss = 2.37993697
# Validation score: 0.590643
# Iteration 76, loss = 2.48169720
# Validation score: 0.754386
# Iteration 77, loss = 1.61900548
# Validation score: 0.783626
# Iteration 78, loss = 1.35510684
# Validation score: 0.789474
# Iteration 79, loss = 1.26093068
# Validation score: 0.742690
# Iteration 80, loss = 1.31377406
# Validation score: 0.766082
# Iteration 81, loss = 1.30740374
# Validation score: 0.760234
# Iteration 82, loss = 1.27350337
# Validation score: 0.748538
# Iteration 83, loss = 1.16471807
# Validation score: 0.766082
# Iteration 84, loss = 1.13794811
# Validation score: 0.783626
# Iteration 85, loss = 1.26684134
# Validation score: 0.777778
# Iteration 86, loss = 1.41858417
# Validation score: 0.719298
# Iteration 87, loss = 1.77124425
# Validation score: 0.771930
# Iteration 88, loss = 1.64223176
# Validation score: 0.777778
# Iteration 89, loss = 1.58131046
# Validation score: 0.748538
# Iteration 90, loss = 1.43100052
# Validation score: 0.760234
# Iteration 91, loss = 1.53241654
# Validation score: 0.771930
# Iteration 92, loss = 1.42374414
# Validation score: 0.801170
# Iteration 93, loss = 1.82866258
# Validation score: 0.695906
# Iteration 94, loss = 2.94359497
# Validation score: 0.771930
# Iteration 95, loss = 1.97897103
# Validation score: 0.736842
# Iteration 96, loss = 2.27632607
# Validation score: 0.567251
# Iteration 97, loss = 2.52314136
# Validation score: 0.555556
# Iteration 98, loss = 7.53660970
# Validation score: 0.690058
# Iteration 99, loss = 10.27998337
# Validation score: 0.666667
# Iteration 100, loss = 5.16333201
# Validation score: 0.526316
# Iteration 101, loss = 6.71919666
# Validation score: 0.742690
# Iteration 102, loss = 6.90852705
# Validation score: 0.707602
# Iteration 103, loss = 7.89671080
# Validation score: 0.584795
# Iteration 104, loss = 3.82498030
# Validation score: 0.742690
# Iteration 105, loss = 2.31948634
# Validation score: 0.730994
# Iteration 106, loss = 2.39013423
# Validation score: 0.754386
# Iteration 107, loss = 2.02681798
# Validation score: 0.660819
# Iteration 108, loss = 2.57900135
# Validation score: 0.783626
# Iteration 109, loss = 1.85210119
# Validation score: 0.742690
# Iteration 110, loss = 1.71571120
# Validation score: 0.695906
# Iteration 111, loss = 1.70107455
# Validation score: 0.672515
# Iteration 112, loss = 2.26110957
# Validation score: 0.736842
# Iteration 113, loss = 1.84266417
# Validation score: 0.730994
# Iteration 114, loss = 1.36698597
# Validation score: 0.736842
# Iteration 115, loss = 1.70876632
# Validation score: 0.719298
# Iteration 116, loss = 1.64266520
# Validation score: 0.678363
# Iteration 117, loss = 2.61228132
# Validation score: 0.649123
# Iteration 118, loss = 5.00160157
# Validation score: 0.777778
# Iteration 119, loss = 3.95961224
# Validation score: 0.760234
# Iteration 120, loss = 2.53410438
# Validation score: 0.777778
# Iteration 121, loss = 2.53213379
# Validation score: 0.707602
# Iteration 122, loss = 3.59473856
# Validation score: 0.695906
# Iteration 123, loss = 2.60589828
# Validation score: 0.742690
# Iteration 124, loss = 1.68702855
# Validation score: 0.742690
# Iteration 125, loss = 1.58936370
# Validation score: 0.766082
# Iteration 126, loss = 1.38527218
# Validation score: 0.771930
# Iteration 127, loss = 1.21044455
# Validation score: 0.783626
# Iteration 128, loss = 1.01689375
# Validation score: 0.742690
# Iteration 129, loss = 0.91439800
# Validation score: 0.777778
# Iteration 130, loss = 0.91080485
# Validation score: 0.748538
# Iteration 131, loss = 0.97758640
# Validation score: 0.789474
# Iteration 132, loss = 0.92115300
# Validation score: 0.748538
# Iteration 133, loss = 1.07678802
# Validation score: 0.748538
# Iteration 134, loss = 0.90395907
# Validation score: 0.795322
# Iteration 135, loss = 0.95733058
# Validation score: 0.754386
# Iteration 136, loss = 0.94137165
# Validation score: 0.783626
# Iteration 137, loss = 0.83290241
# Validation score: 0.760234
# Iteration 138, loss = 0.73939932
# Validation score: 0.789474
# Iteration 139, loss = 0.74326560
# Validation score: 0.795322
# Iteration 140, loss = 0.78028961
# Validation score: 0.771930
# Iteration 141, loss = 0.89436292
# Validation score: 0.660819
# Iteration 142, loss = 1.53702076
# Validation score: 0.777778
# Iteration 143, loss = 1.10104440
# Validation score: 0.795322
# Iteration 144, loss = 1.10264200
# Validation score: 0.795322
# Iteration 145, loss = 0.90460835
# Validation score: 0.795322
# Iteration 146, loss = 0.89907120
# Validation score: 0.789474
# Iteration 147, loss = 0.83319479
# Validation score: 0.766082
# Iteration 148, loss = 0.79038966
# Validation score: 0.760234
# Iteration 149, loss = 0.70076950
# Validation score: 0.795322
# Iteration 150, loss = 0.76334023
# Validation score: 0.760234
# Iteration 151, loss = 0.71732514
# Validation score: 0.771930
# Iteration 152, loss = 0.78699664
# Validation score: 0.777778
# Iteration 153, loss = 0.79149805
# Validation score: 0.766082
# Iteration 154, loss = 0.90897389
# Validation score: 0.783626
# Iteration 155, loss = 1.08076205
# Validation score: 0.730994
# Iteration 156, loss = 1.23339793
# Validation score: 0.777778
# Iteration 157, loss = 1.14731308
# Validation score: 0.777778
# Iteration 158, loss = 0.86143071
# Validation score: 0.789474
# Iteration 159, loss = 0.83327988
# Validation score: 0.789474
# Iteration 160, loss = 0.81603579
# Validation score: 0.783626
# Iteration 161, loss = 0.72366828
# Validation score: 0.760234
# Iteration 162, loss = 0.75063769
# Validation score: 0.789474
# Iteration 163, loss = 0.82949318
# Validation score: 0.766082
# Iteration 164, loss = 0.70916163
# Validation score: 0.777778
# Iteration 165, loss = 0.85071741
# Validation score: 0.777778
# Iteration 166, loss = 1.22055573
# Validation score: 0.783626
# Iteration 167, loss = 1.85680600
# Validation score: 0.789474
# Iteration 168, loss = 2.33826704
# Validation score: 0.777778
# Iteration 169, loss = 1.81079354
# Validation score: 0.713450
# Iteration 170, loss = 1.50997207
# Validation score: 0.766082
# Iteration 171, loss = 1.53573776
# Validation score: 0.736842
# Iteration 172, loss = 1.39051462
# Validation score: 0.795322
# Iteration 173, loss = 0.93096847
# Validation score: 0.789474
# Iteration 174, loss = 0.81100530
# Validation score: 0.795322
# Iteration 175, loss = 0.86201049
# Validation score: 0.766082
# Iteration 176, loss = 0.75767051
# Validation score: 0.795322
# Iteration 177, loss = 0.74061597
# Validation score: 0.754386
# Iteration 178, loss = 0.74557221
# Validation score: 0.771930
# Iteration 179, loss = 0.70438805
# Validation score: 0.795322
# Iteration 180, loss = 0.72530251
# Validation score: 0.742690
# Iteration 181, loss = 0.64542868
# Validation score: 0.801170
# Iteration 182, loss = 0.70579283
# Validation score: 0.783626
# Iteration 183, loss = 0.74877204
# Validation score: 0.783626
# Validation score did not improve more than tol=0.000100 for 90 consecutive epochs. Stopping.
# MLPClassifier(activation='relu', alpha=1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(100, 100), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=90, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=10,
#               warm_start=False)
# Score =  0.8210526315789474
# [9.36343445e-25 1.64667129e-27 3.01478943e-35 4.12945988e-32
#  1.11367969e-29 1.52618479e-60 1.41832909e-38 1.75887034e-26
#  8.32811597e-21 9.72618445e-44 5.10621943e-26 1.18200746e-48
#  3.69572814e-02 5.56863918e-24 5.97225674e-30 2.09853482e-15
#  1.40694971e-24 1.80374855e-30 2.08673233e-47 1.89509619e-18
#  1.30342831e-20 1.55025811e-38 4.11667278e-06 2.51996668e-07
#  1.07895684e-33 1.40825010e-18 1.62269467e-17 1.54657556e-19
#  6.67301106e-59 3.71418177e-01 5.03743994e-26 9.94029608e-01
#  1.00000000e+00 2.09481195e-22 3.95640138e-58 7.40047719e-25
#  1.72449779e-47 2.11907368e-30 2.56812969e-15 2.25999209e-33
#  3.31613468e-34 4.71755115e-09 7.24271721e-19 3.71333212e-42
#  1.82197040e-15 1.19420186e-12 4.75818910e-36 3.14689146e-26
#  1.65978038e-30 2.28616506e-15 1.62459049e-17 1.28400475e-20
#  9.70770915e-12 3.23730894e-19 4.32974677e-27 3.91610660e-30
#  3.62972513e-27 2.55560518e-38 1.93319357e-38 4.48314818e-26
#  4.84142602e-55 6.66466387e-40 3.20362077e-34 4.59958437e-25
#  3.86746854e-19 2.68886797e-02 2.63705508e-25 8.47124181e-30
#  3.22350455e-36 9.55889842e-41 5.11727672e-29 1.61954158e-22
#  9.99999054e-01 3.83118191e-07 2.53620595e-49 6.65011184e-25
#  6.92463648e-09 3.85747934e-29 2.48426714e-40 1.18555786e-13
#  1.55803515e-26 5.86182488e-55 1.17362548e-38 6.11370424e-18
#  4.10161541e-49 5.73694637e-11 7.73938115e-24 9.93170121e-21
#  5.35397110e-29 9.99999998e-01 3.53877893e-37 3.31732719e-10
#  9.46255023e-13 3.30944785e-04 1.03235712e-52 5.49353289e-40
#  3.50593629e-26 1.18923264e-12 2.01543715e-45 1.84150790e-44
#  1.26030366e-30 3.76119977e-24 3.03357333e-26 2.51109699e-10
#  3.12472649e-15 8.99322688e-10 1.99940507e-19 1.55632305e-02
#  2.34851670e-37 1.55028491e-28 2.63518690e-09 1.83717863e-37
#  1.11251686e-17 7.96246657e-01 2.39589978e-26 5.19169806e-19
#  4.27167818e-44 1.00000000e+00 1.71925877e-31 6.73156780e-01
#  1.32945736e-30 2.01901063e-27 4.97397707e-34 5.08032699e-13
#  6.75647809e-19 1.00000000e+00 7.07474399e-42 1.00000000e+00
#  2.02245663e-51 3.37501568e-27 1.73037654e-04 2.90422559e-02
#  3.04659658e-07 1.62388762e-24 1.72167223e-25 1.46094471e-23
#  8.35426274e-33 5.25927550e-28 1.42146641e-24 5.73537034e-48
#  2.19286092e-28 6.99250093e-10 3.23062992e-40 9.99992886e-01
#  2.14545765e-01 5.19704718e-19 2.51433047e-36 5.75326083e-37
#  1.80119726e-14 8.38783120e-25 3.14578081e-22 5.00000066e-32
#  6.19205124e-52 2.89662000e-15 3.48921130e-31 3.03731891e-20
#  1.65987078e-32 1.52266356e-48 2.67155523e-31 7.90030832e-33
#  9.05230911e-15 2.28849500e-34 5.42411059e-13 1.00000000e+00
#  1.51230813e-12 8.39090446e-06 1.18713762e-42 3.50430492e-19
#  4.11984427e-14 1.81400617e-07 9.99181270e-01 3.55900725e-35
#  1.55655075e-49 4.80510433e-38 4.63616632e-16 2.20181665e-22
#  8.55082068e-14 1.29458841e-31 1.95701288e-23 1.62203223e-29
#  1.95772235e-23 1.91702284e-15 2.18090648e-25 5.95030334e-21
#  7.46375931e-38 6.33495471e-40 3.94867819e-32 2.17946501e-13
#  2.72703883e-26 1.65210764e-41 1.34707990e-22 6.50338379e-28
#  1.99674324e-26 3.22761953e-15 8.94220347e-15 3.25293571e-23
#  9.99486074e-01 5.22380945e-48 5.35838036e-17 2.88875369e-10
#  3.12003911e-17 1.97108719e-25 1.69219152e-47 1.09630653e-35
#  1.97341939e-28 3.66389312e-40 2.12796632e-17 9.23271133e-11
#  2.01208188e-32 1.03889563e-40 5.87208050e-15 5.25866841e-25
#  2.12684750e-26 1.81168976e-24 2.35217474e-25 9.99988549e-01
#  2.70397733e-25 4.38471744e-45 5.09741112e-23 2.28001990e-38
#  3.55759095e-23 2.05634115e-19 4.24291189e-23 9.49269953e-03
#  9.98171575e-01 4.33596990e-31 6.10221131e-12 4.13457892e-32
#  1.91241082e-31 2.95296948e-34 1.52519484e-19 6.68586133e-21
#  2.95384636e-20 3.32779058e-25 5.26378631e-25 4.27089012e-22
#  1.33735922e-42 1.84779600e-39 2.97049177e-39 1.72405554e-45
#  1.00000000e+00 1.01403226e-54 2.43577867e-32 1.29049932e-10
#  6.48349965e-46 2.46688501e-30 2.00257675e-20 3.84567177e-23
#  1.54472108e-27 1.64859787e-30 9.97684977e-01 3.81752407e-31
#  4.43602826e-11 8.67192003e-19 8.67162879e-33 3.34665192e-25
#  1.00000000e+00 2.04565702e-24 2.21848335e-15 1.19331144e-13
#  6.88128426e-26 9.15212540e-45 1.85097787e-38 5.87266646e-07
#  6.42990474e-22 1.81732149e-25 9.54777013e-01 8.21362809e-12
#  1.25557142e-18 9.96348814e-46 7.94662024e-21 2.39199653e-32
#  3.96045895e-21 2.30068027e-05 1.12417004e-19 8.28197920e-11
#  6.46892280e-17 6.20120817e-16 8.77244627e-23 5.99052044e-22
#  2.19769940e-29 8.88484150e-16 4.32901595e-42 7.57410159e-05
#  5.62861804e-38]

# %% [markdown]
# # **Plot loss**

# %%
fig=plt.figure(figsize=(7,7))

plt.plot(clf.loss_curve_)
#Warning: thiscan be usedonly if early_stopping=True
print(clf.validation_scores_)
plt.plot(np.asarray(clf.validation_scores_))

plt.show()
fig=plt.figure(figsize=(7,7))

#plt.plot(clf.loss_curve_)
#Warning: thiscan be usedonly if early_stopping=True

plt.plot(np.asarray(clf.validation_scores_))

plt.show()
# Out:
# [0.07602339181286549, 0.3742690058479532, 0.52046783625731, 0.07602339181286549, 0.52046783625731, 0.08187134502923976, 0.1111111111111111, 0.52046783625731, 0.15204678362573099, 0.5263157894736842, 0.47368421052631576, 0.4152046783625731, 0.5497076023391813, 0.15789473684210525, 0.5497076023391813, 0.5029239766081871, 0.5555555555555556, 0.6257309941520468, 0.543859649122807, 0.4619883040935672, 0.543859649122807, 0.543859649122807, 0.6257309941520468, 0.6257309941520468, 0.631578947368421, 0.6140350877192983, 0.631578947368421, 0.5614035087719298, 0.5730994152046783, 0.6432748538011696, 0.6842105263157895, 0.6432748538011696, 0.49122807017543857, 0.47953216374269003, 0.6198830409356725, 0.7076023391812866, 0.5730994152046783, 0.6491228070175439, 0.7134502923976608, 0.6140350877192983, 0.47368421052631576, 0.6081871345029239, 0.36257309941520466, 0.14035087719298245, 0.38596491228070173, 0.3508771929824561, 0.4853801169590643, 0.5847953216374269, 0.6198830409356725, 0.6257309941520468, 0.672514619883041, 0.6257309941520468, 0.695906432748538, 0.695906432748538, 0.6608187134502924, 0.7309941520467836, 0.7602339181286549, 0.7426900584795322, 0.7251461988304093, 0.7309941520467836, 0.7543859649122807, 0.7719298245614035, 0.7485380116959064, 0.7485380116959064, 0.7134502923976608, 0.7076023391812866, 0.7251461988304093, 0.695906432748538, 0.7602339181286549, 0.7543859649122807, 0.7309941520467836, 0.7368421052631579, 0.7543859649122807, 0.7309941520467836, 0.5906432748538012, 0.7543859649122807, 0.783625730994152, 0.7894736842105263, 0.7426900584795322, 0.7660818713450293, 0.7602339181286549, 0.7485380116959064, 0.7660818713450293, 0.783625730994152, 0.7777777777777778, 0.7192982456140351, 0.7719298245614035, 0.7777777777777778, 0.7485380116959064, 0.7602339181286549, 0.7719298245614035, 0.8011695906432749, 0.695906432748538, 0.7719298245614035, 0.7368421052631579, 0.5672514619883041, 0.5555555555555556, 0.6900584795321637, 0.6666666666666666, 0.5263157894736842, 0.7426900584795322, 0.7076023391812866, 0.5847953216374269, 0.7426900584795322, 0.7309941520467836, 0.7543859649122807, 0.6608187134502924, 0.783625730994152, 0.7426900584795322, 0.695906432748538, 0.672514619883041, 0.7368421052631579, 0.7309941520467836, 0.7368421052631579, 0.7192982456140351, 0.6783625730994152, 0.6491228070175439, 0.7777777777777778, 0.7602339181286549, 0.7777777777777778, 0.7076023391812866, 0.695906432748538, 0.7426900584795322, 0.7426900584795322, 0.7660818713450293, 0.7719298245614035, 0.783625730994152, 0.7426900584795322, 0.7777777777777778, 0.7485380116959064, 0.7894736842105263, 0.7485380116959064, 0.7485380116959064, 0.7953216374269005, 0.7543859649122807, 0.783625730994152, 0.7602339181286549, 0.7894736842105263, 0.7953216374269005, 0.7719298245614035, 0.6608187134502924, 0.7777777777777778, 0.7953216374269005, 0.7953216374269005, 0.7953216374269005, 0.7894736842105263, 0.7660818713450293, 0.7602339181286549, 0.7953216374269005, 0.7602339181286549, 0.7719298245614035, 0.7777777777777778, 0.7660818713450293, 0.783625730994152, 0.7309941520467836, 0.7777777777777778, 0.7777777777777778, 0.7894736842105263, 0.7894736842105263, 0.783625730994152, 0.7602339181286549, 0.7894736842105263, 0.7660818713450293, 0.7777777777777778, 0.7777777777777778, 0.783625730994152, 0.7894736842105263, 0.7777777777777778, 0.7134502923976608, 0.7660818713450293, 0.7368421052631579, 0.7953216374269005, 0.7894736842105263, 0.7953216374269005, 0.7660818713450293, 0.7953216374269005, 0.7543859649122807, 0.7719298245614035, 0.7953216374269005, 0.7426900584795322, 0.8011695906432749, 0.783625730994152, 0.783625730994152]

# %% [markdown]
# # **Plot results**

# %% [markdown]
# ![faces_2.png](data:image/png;base64,...)

# %%
# Plot the prediction
predicted = clf.predict(X_test)
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(24, 24)) # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)
for i in range(100):
  ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
  ax.imshow(X_test[i].reshape(h,w), cmap=plt.cm.gray, interpolation='nearest')
  # label the image with the target value
  if y_test[i]== predicted[i]:
    ax.text(0, 5, str(target_names[y_test[i]]) + str(target_names[predicted[i]]),color='blue') 
  else:
    ax.text(0, 5, str(target_names[y_test[i]]) + str(target_names[predicted[i]]),color='red')

# %% [markdown]
# Print the classification report

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.73      0.82        64
#            1       0.66      0.72      0.69        32
#            2       0.85      0.89      0.87       127
#            3       0.82      0.79      0.81        29
#            4       0.71      0.82      0.76        33
#
#     accuracy                           0.82       285
#    macro avg       0.79      0.79      0.79       285
# weighted avg       0.83      0.82      0.82       285

# %% [markdown]
# # **Print the confusion matrix (expected true label vs. the reconstructed label)**

# %%
print(metrics.confusion_matrix(y_test, predicted))
# Out:
# [[ 47   4   8   1   4]
#  [  0  23   5   0   4]
#  [  4   7 113   3   0]
#  [  0   0   3  23   3]
#  [  0   1   4   1  27]]

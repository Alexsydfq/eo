# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexsydfq/eo/blob/main/Kopia_notatnika_cwiczenia_1a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Przykład z wykładu prof. Broniowskiego**
# Inżynieria danych 2019/20
# Wersja z 18.04.2020

# %% [markdown]
# # To samo ale z użyciem pakietu Scikit Learn https://scikit-learn.org

# %% [markdown]
# # Załączone pakiety

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib as mpl

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# # Przykład z punktami w kole

# %%
# zwraca losowe współrzędne x1, x2 oraz 1 dla punktów 
# w kole o środku (0.5,0.5) i promeniu 0.4, a 0 poza nim

def romb():
    x1=random.random()
    x2=random.random()
    if (x2>0.3) and (x2<0.7) and (x2>x1-0.27) and (x2<x1+0.27): # w kole
        return np.array([x1,x2,1])
    else:                                              # poza kołem
        return np.array([x1,x2,0])

# %% [markdown]
# # `Przygotowanie danych`

# %%
probka_k=np.array([romb() for i in range(6000)])
print(probka_k.shape)
# Out:
# (6000, 3)

# %% [markdown]
# # Definiuję funkcję rysującą dane

# %%
def draw_result(X,y): 
  fig=plt.figure(figsize=(5,5))

  # dorysowanie okręgu
  #ax=fig.add_subplot(1,1,1)
  #circ=plt.Circle((0.5,0.5), radius=.4, color='black', fill=False)
  #ax.add_patch(circ)

  plt.title("Działanie na próbce testowej",fontsize=16) 
  plt.xlim(min(X[:,0]),max(X[:,0]))
  plt.ylim(min(X[:,1]),max(X[:,1]))
  plt.scatter(X[:,0],X[:,1],c=y,
            s=5,cmap=mpl.cm.cool,norm=mpl.colors.Normalize(vmin=min(y), vmax=max(y)))

  plt.xlabel('$x_1$',fontsize=18)
  plt.ylabel('$x_2$',fontsize=18);

# %% [markdown]
# # Przygotowanie formatu danych

# %%
X, y = probka_k[:,:2], probka_k[:,2]

X = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5, random_state=42)

print("Shapes of datasets X_train, X_test, y_train, y_test: ",X_train.shape, X_test.shape, y_train.shape, y_test.shape)

#narysuj dane testowe
draw_result(X_test, y_test)
# Out:
# Shapes of datasets X_train, X_test, y_train, y_test:  (3000, 2) (3000, 2) (3000,) (3000,)

# %% [markdown]
# # **Trening**
#
# Instrukcja użycia Multi Layer Perceptron
# https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html#sklearn.neural_network.MLPClassifier

# %%
clf = MLPClassifier(hidden_layer_sizes=(5,5), activation='tanh', alpha=0.1, 
                    learning_rate_init=0.01, early_stopping=True,validation_fraction=0.2,verbose=True,n_iter_no_change=100,max_iter=1000)
                    #max_iter=1000) 


print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# get prediction
Z = clf.predict_proba(X_test)[:,1] # returns probability 
print(Z)
# Out:
# Iteration 1, loss = 0.61172364
# Validation score: 0.800000
# Iteration 2, loss = 0.53716665
# Validation score: 0.800000
# Iteration 3, loss = 0.51750654
# Validation score: 0.800000
# Iteration 4, loss = 0.49839304
# Validation score: 0.800000
# Iteration 5, loss = 0.47229753
# Validation score: 0.800000
# Iteration 6, loss = 0.43245922
# Validation score: 0.800000
# Iteration 7, loss = 0.38059643
# Validation score: 0.800000
# Iteration 8, loss = 0.32666098
# Validation score: 0.905000
# Iteration 9, loss = 0.27959796
# Validation score: 0.901667
# Iteration 10, loss = 0.24488105
# Validation score: 0.950000
# Iteration 11, loss = 0.21332811
# Validation score: 0.951667
# Iteration 12, loss = 0.18906573
# Validation score: 0.958333
# Iteration 13, loss = 0.16956794
# Validation score: 0.963333
# Iteration 14, loss = 0.15480314
# Validation score: 0.966667
# Iteration 15, loss = 0.14480093
# Validation score: 0.960000
# Iteration 16, loss = 0.13886724
# Validation score: 0.953333
# Iteration 17, loss = 0.13142752
# Validation score: 0.963333
# Iteration 18, loss = 0.12453387
# Validation score: 0.965000
# Iteration 19, loss = 0.12053727
# Validation score: 0.965000
# Iteration 20, loss = 0.11763054
# Validation score: 0.965000
# Iteration 21, loss = 0.11446526
# Validation score: 0.963333
# Iteration 22, loss = 0.11201990
# Validation score: 0.960000
# Iteration 23, loss = 0.11036586
# Validation score: 0.966667
# Iteration 24, loss = 0.10956060
# Validation score: 0.965000
# Iteration 25, loss = 0.10710943
# Validation score: 0.956667
# Iteration 26, loss = 0.10765852
# Validation score: 0.966667
# Iteration 27, loss = 0.10455964
# Validation score: 0.966667
# Iteration 28, loss = 0.10240330
# Validation score: 0.961667
# Iteration 29, loss = 0.10148704
# Validation score: 0.966667
# Iteration 30, loss = 0.10117773
# Validation score: 0.960000
# Iteration 31, loss = 0.09960311
# Validation score: 0.965000
# Iteration 32, loss = 0.10262688
# Validation score: 0.968333
# Iteration 33, loss = 0.10011118
# Validation score: 0.963333
# Iteration 34, loss = 0.09637187
# Validation score: 0.966667
# Iteration 35, loss = 0.09730436
# Validation score: 0.965000
# Iteration 36, loss = 0.09579639
# Validation score: 0.966667
# Iteration 37, loss = 0.09607367
# Validation score: 0.961667
# Iteration 38, loss = 0.10134171
# Validation score: 0.966667
# Iteration 39, loss = 0.09804202
# Validation score: 0.970000
# Iteration 40, loss = 0.09511407
# Validation score: 0.961667
# Iteration 41, loss = 0.09367235
# Validation score: 0.971667
# Iteration 42, loss = 0.09427437
# Validation score: 0.960000
# Iteration 43, loss = 0.09246330
# Validation score: 0.970000
# Iteration 44, loss = 0.09035878
# Validation score: 0.963333
# Iteration 45, loss = 0.09117730
# Validation score: 0.966667
# Iteration 46, loss = 0.09137614
# Validation score: 0.968333
# Iteration 47, loss = 0.09102904
# Validation score: 0.970000
# Iteration 48, loss = 0.09059142
# Validation score: 0.961667
# Iteration 49, loss = 0.08931070
# Validation score: 0.970000
# Iteration 50, loss = 0.08938179
# Validation score: 0.963333
# Iteration 51, loss = 0.08880562
# Validation score: 0.966667
# Iteration 52, loss = 0.08967627
# Validation score: 0.963333
# Iteration 53, loss = 0.08814483
# Validation score: 0.970000
# Iteration 54, loss = 0.08764177
# Validation score: 0.973333
# Iteration 55, loss = 0.08743380
# Validation score: 0.961667
# Iteration 56, loss = 0.09075568
# Validation score: 0.975000
# Iteration 57, loss = 0.08540181
# Validation score: 0.968333
# Iteration 58, loss = 0.08552942
# Validation score: 0.963333
# Iteration 59, loss = 0.08573506
# Validation score: 0.973333
# Iteration 60, loss = 0.08560934
# Validation score: 0.968333
# Iteration 61, loss = 0.08470588
# Validation score: 0.971667
# Iteration 62, loss = 0.08425885
# Validation score: 0.975000
# Iteration 63, loss = 0.08445340
# Validation score: 0.966667
# Iteration 64, loss = 0.08437370
# Validation score: 0.975000
# Iteration 65, loss = 0.08165320
# Validation score: 0.976667
# Iteration 66, loss = 0.08330800
# Validation score: 0.975000
# Iteration 67, loss = 0.08137301
# Validation score: 0.970000
# Iteration 68, loss = 0.08215022
# Validation score: 0.975000
# Iteration 69, loss = 0.08122504
# Validation score: 0.975000
# Iteration 70, loss = 0.08304020
# Validation score: 0.975000
# Iteration 71, loss = 0.08654625
# Validation score: 0.973333
# Iteration 72, loss = 0.08119647
# Validation score: 0.975000
# Iteration 73, loss = 0.08150702
# Validation score: 0.980000
# Iteration 74, loss = 0.08021343
# Validation score: 0.975000
# Iteration 75, loss = 0.08052452
# Validation score: 0.973333
# Iteration 76, loss = 0.08044453
# Validation score: 0.978333
# Iteration 77, loss = 0.08046386
# Validation score: 0.983333
# Iteration 78, loss = 0.08071820
# Validation score: 0.973333
# Iteration 79, loss = 0.08091766
# Validation score: 0.970000
# Iteration 80, loss = 0.08021888
# Validation score: 0.975000
# Iteration 81, loss = 0.07982039
# Validation score: 0.973333
# Iteration 82, loss = 0.08214209
# Validation score: 0.975000
# Iteration 83, loss = 0.07956061
# Validation score: 0.971667
# Iteration 84, loss = 0.07948750
# Validation score: 0.976667
# Iteration 85, loss = 0.07924271
# Validation score: 0.978333
# Iteration 86, loss = 0.07824115
# Validation score: 0.975000
# Iteration 87, loss = 0.08027236
# Validation score: 0.975000
# Iteration 88, loss = 0.07839555
# Validation score: 0.971667
# Iteration 89, loss = 0.07867386
# Validation score: 0.981667
# Iteration 90, loss = 0.08232157
# Validation score: 0.980000
# Iteration 91, loss = 0.08725191
# Validation score: 0.976667
# Iteration 92, loss = 0.07968730
# Validation score: 0.973333
# Iteration 93, loss = 0.07874371
# Validation score: 0.980000
# Iteration 94, loss = 0.07822225
# Validation score: 0.978333
# Iteration 95, loss = 0.07885159
# Validation score: 0.973333
# Iteration 96, loss = 0.07872411
# Validation score: 0.978333
# Iteration 97, loss = 0.07593730
# Validation score: 0.975000
# Iteration 98, loss = 0.07727866
# Validation score: 0.965000
# Iteration 99, loss = 0.07986362
# Validation score: 0.971667
# Iteration 100, loss = 0.07743319
# Validation score: 0.980000
# Iteration 101, loss = 0.07640271
# Validation score: 0.981667
# Iteration 102, loss = 0.07748811
# Validation score: 0.971667
# Iteration 103, loss = 0.07835758
# Validation score: 0.975000
# Iteration 104, loss = 0.07655953
# Validation score: 0.973333
# Iteration 105, loss = 0.07656369
# Validation score: 0.980000
# Iteration 106, loss = 0.07600062
# Validation score: 0.980000
# Iteration 107, loss = 0.07513092
# Validation score: 0.980000
# Iteration 108, loss = 0.07591114
# Validation score: 0.981667
# Iteration 109, loss = 0.07649940
# Validation score: 0.973333
# Iteration 110, loss = 0.07591526
# Validation score: 0.978333
# Iteration 111, loss = 0.07478973
# Validation score: 0.978333
# Iteration 112, loss = 0.07638114
# Validation score: 0.980000
# Iteration 113, loss = 0.07855349
# Validation score: 0.978333
# Iteration 114, loss = 0.07781078
# Validation score: 0.976667
# Iteration 115, loss = 0.07679661
# Validation score: 0.975000
# Iteration 116, loss = 0.07682873
# Validation score: 0.970000
# Iteration 117, loss = 0.07703586
# Validation score: 0.980000
# Iteration 118, loss = 0.07453368
# Validation score: 0.980000
# Iteration 119, loss = 0.07470543
# Validation score: 0.978333
# Iteration 120, loss = 0.07522793
# Validation score: 0.975000
# Iteration 121, loss = 0.07768367
# Validation score: 0.981667
# Iteration 122, loss = 0.08171119
# Validation score: 0.978333
# Iteration 123, loss = 0.08002605
# Validation score: 0.976667
# Iteration 124, loss = 0.07579321
# Validation score: 0.973333
# Iteration 125, loss = 0.07632999
# Validation score: 0.978333
# Iteration 126, loss = 0.07375834
# Validation score: 0.981667
# Iteration 127, loss = 0.07354740
# Validation score: 0.980000
# Iteration 128, loss = 0.07357657
# Validation score: 0.980000
# Iteration 129, loss = 0.07423396
# Validation score: 0.975000
# Iteration 130, loss = 0.07711384
# Validation score: 0.980000
# Iteration 131, loss = 0.07611224
# Validation score: 0.978333
# Iteration 132, loss = 0.07356885
# Validation score: 0.973333
# Iteration 133, loss = 0.07841540
# Validation score: 0.983333
# Iteration 134, loss = 0.07587740
# Validation score: 0.980000
# Iteration 135, loss = 0.07494145
# Validation score: 0.978333
# Iteration 136, loss = 0.07333181
# Validation score: 0.976667
# Iteration 137, loss = 0.07435703
# Validation score: 0.976667
# Iteration 138, loss = 0.07436263
# Validation score: 0.976667
# Iteration 139, loss = 0.07610737
# Validation score: 0.976667
# Iteration 140, loss = 0.07352671
# Validation score: 0.983333
# Iteration 141, loss = 0.07271293
# Validation score: 0.975000
# Iteration 142, loss = 0.07861650
# Validation score: 0.970000
# Iteration 143, loss = 0.07953260
# Validation score: 0.986667
# Iteration 144, loss = 0.07725282
# Validation score: 0.971667
# Iteration 145, loss = 0.07372493
# Validation score: 0.978333
# Iteration 146, loss = 0.07582657
# Validation score: 0.978333
# Iteration 147, loss = 0.07320041
# Validation score: 0.980000
# Iteration 148, loss = 0.07227919
# Validation score: 0.980000
# Iteration 149, loss = 0.07217187
# Validation score: 0.976667
# Iteration 150, loss = 0.07302956
# Validation score: 0.985000
# Iteration 151, loss = 0.07207976
# Validation score: 0.980000
# Iteration 152, loss = 0.07298601
# Validation score: 0.978333
# Iteration 153, loss = 0.07341053
# Validation score: 0.978333
# Iteration 154, loss = 0.07280424
# Validation score: 0.980000
# Iteration 155, loss = 0.07327034
# Validation score: 0.978333
# Iteration 156, loss = 0.07257723
# Validation score: 0.986667
# Iteration 157, loss = 0.07283570
# Validation score: 0.975000
# Iteration 158, loss = 0.07310498
# Validation score: 0.978333
# Iteration 159, loss = 0.07192154
# Validation score: 0.978333
# Iteration 160, loss = 0.07358246
# Validation score: 0.983333
# Iteration 161, loss = 0.07531879
# Validation score: 0.980000
# Iteration 162, loss = 0.07396970
# Validation score: 0.980000
# Iteration 163, loss = 0.07133745
# Validation score: 0.983333
# Iteration 164, loss = 0.07332044
# Validation score: 0.975000
# Iteration 165, loss = 0.07559462
# Validation score: 0.980000
# Iteration 166, loss = 0.07374411
# Validation score: 0.980000
# Iteration 167, loss = 0.07306667
# Validation score: 0.983333
# Iteration 168, loss = 0.07277900
# Validation score: 0.981667
# Iteration 169, loss = 0.07218941
# Validation score: 0.980000
# Iteration 170, loss = 0.07191214
# Validation score: 0.978333
# Iteration 171, loss = 0.07353476
# Validation score: 0.978333
# Iteration 172, loss = 0.07149994
# Validation score: 0.978333
# Iteration 173, loss = 0.07303739
# Validation score: 0.983333
# Iteration 174, loss = 0.07793043
# Validation score: 0.983333
# Iteration 175, loss = 0.07596439
# Validation score: 0.971667
# Iteration 176, loss = 0.07351294
# Validation score: 0.980000
# Iteration 177, loss = 0.07413197
# Validation score: 0.971667
# Iteration 178, loss = 0.07287857
# Validation score: 0.968333
# Iteration 179, loss = 0.07410655
# Validation score: 0.973333
# Iteration 180, loss = 0.07271543
# Validation score: 0.985000
# Iteration 181, loss = 0.07044390
# Validation score: 0.980000
# Iteration 182, loss = 0.07210373
# Validation score: 0.985000
# Iteration 183, loss = 0.07362289
# Validation score: 0.978333
# Iteration 184, loss = 0.07107703
# Validation score: 0.980000
# Iteration 185, loss = 0.07075875
# Validation score: 0.980000
# Iteration 186, loss = 0.07103145
# Validation score: 0.983333
# Iteration 187, loss = 0.07187131
# Validation score: 0.985000
# Iteration 188, loss = 0.07131664
# Validation score: 0.976667
# Iteration 189, loss = 0.07159122
# Validation score: 0.981667
# Iteration 190, loss = 0.07136779
# Validation score: 0.985000
# Iteration 191, loss = 0.07273992
# Validation score: 0.973333
# Iteration 192, loss = 0.07132158
# Validation score: 0.983333
# Iteration 193, loss = 0.07176484
# Validation score: 0.983333
# Iteration 194, loss = 0.07126141
# Validation score: 0.986667
# Iteration 195, loss = 0.07112428
# Validation score: 0.983333
# Iteration 196, loss = 0.07019414
# Validation score: 0.978333
# Iteration 197, loss = 0.07129945
# Validation score: 0.981667
# Iteration 198, loss = 0.07182286
# Validation score: 0.978333
# Iteration 199, loss = 0.07113632
# Validation score: 0.978333
# Iteration 200, loss = 0.07162669
# Validation score: 0.976667
# Iteration 201, loss = 0.07397862
# Validation score: 0.981667
# Iteration 202, loss = 0.07073170
# Validation score: 0.983333
# Iteration 203, loss = 0.07260217
# Validation score: 0.980000
# Iteration 204, loss = 0.07143054
# Validation score: 0.978333
# Iteration 205, loss = 0.07242401
# Validation score: 0.976667
# Iteration 206, loss = 0.07183904
# Validation score: 0.978333
# Iteration 207, loss = 0.07122612
# Validation score: 0.985000
# Iteration 208, loss = 0.07161796
# Validation score: 0.981667
# Iteration 209, loss = 0.07151409
# Validation score: 0.978333
# Iteration 210, loss = 0.07017462
# Validation score: 0.975000
# Iteration 211, loss = 0.07068620
# Validation score: 0.983333
# Iteration 212, loss = 0.07255994
# Validation score: 0.986667
# Iteration 213, loss = 0.07696853
# Validation score: 0.973333
# Iteration 214, loss = 0.07939387
# Validation score: 0.986667
# Iteration 215, loss = 0.07249567
# Validation score: 0.976667
# Iteration 216, loss = 0.07323144
# Validation score: 0.978333
# Iteration 217, loss = 0.07179907
# Validation score: 0.983333
# Iteration 218, loss = 0.07203628
# Validation score: 0.980000
# Iteration 219, loss = 0.07200694
# Validation score: 0.978333
# Iteration 220, loss = 0.07108072
# Validation score: 0.978333
# Iteration 221, loss = 0.07243101
# Validation score: 0.978333
# Iteration 222, loss = 0.07039421
# Validation score: 0.981667
# Iteration 223, loss = 0.07275115
# Validation score: 0.980000
# Iteration 224, loss = 0.07087653
# Validation score: 0.983333
# Iteration 225, loss = 0.07050611
# Validation score: 0.985000
# Iteration 226, loss = 0.07014200
# Validation score: 0.983333
# Iteration 227, loss = 0.07012742
# Validation score: 0.985000
# Iteration 228, loss = 0.07051107
# Validation score: 0.980000
# Iteration 229, loss = 0.07073175
# Validation score: 0.983333
# Iteration 230, loss = 0.07194979
# Validation score: 0.978333
# Iteration 231, loss = 0.07198231
# Validation score: 0.976667
# Iteration 232, loss = 0.07209621
# Validation score: 0.983333
# Iteration 233, loss = 0.07060184
# Validation score: 0.981667
# Iteration 234, loss = 0.07213622
# Validation score: 0.983333
# Iteration 235, loss = 0.07096313
# Validation score: 0.976667
# Iteration 236, loss = 0.07014236
# Validation score: 0.978333
# Iteration 237, loss = 0.07138634
# Validation score: 0.980000
# Iteration 238, loss = 0.07446196
# Validation score: 0.985000
# Iteration 239, loss = 0.07089191
# Validation score: 0.981667
# Iteration 240, loss = 0.07272918
# Validation score: 0.975000
# Iteration 241, loss = 0.07470783
# Validation score: 0.981667
# Iteration 242, loss = 0.07169631
# Validation score: 0.983333
# Iteration 243, loss = 0.07165880
# Validation score: 0.981667
# Iteration 244, loss = 0.07245518
# Validation score: 0.978333
# Validation score did not improve more than tol=0.000100 for 100 consecutive epochs. Stopping.
# MLPClassifier(activation='tanh', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=True, epsilon=1e-08,
#               hidden_layer_sizes=(5, 5), learning_rate='constant',
#               learning_rate_init=0.01, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=100, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.2, verbose=True,
#               warm_start=False)
# Score =  0.9796666666666667
# [1.01372166e-03 1.55146191e-03 9.63983562e-01 ... 9.76838036e-01
#  9.90852471e-01 6.94089918e-05]

# %% [markdown]
# # Plot training andvalidation loss

# %%
fig=plt.figure(figsize=(7,7))

plt.plot(clf.loss_curve_)
#Warning: thiscan be usedonly if early_stopping=True
print(clf.validation_scores_)
plt.plot(np.asarray(clf.validation_scores_))

plt.show()
# Out:
# [0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.8, 0.905, 0.9016666666666666, 0.95, 0.9516666666666667, 0.9583333333333334, 0.9633333333333334, 0.9666666666666667, 0.96, 0.9533333333333334, 0.9633333333333334, 0.965, 0.965, 0.965, 0.9633333333333334, 0.96, 0.9666666666666667, 0.965, 0.9566666666666667, 0.9666666666666667, 0.9666666666666667, 0.9616666666666667, 0.9666666666666667, 0.96, 0.965, 0.9683333333333334, 0.9633333333333334, 0.9666666666666667, 0.965, 0.9666666666666667, 0.9616666666666667, 0.9666666666666667, 0.97, 0.9616666666666667, 0.9716666666666667, 0.96, 0.97, 0.9633333333333334, 0.9666666666666667, 0.9683333333333334, 0.97, 0.9616666666666667, 0.97, 0.9633333333333334, 0.9666666666666667, 0.9633333333333334, 0.97, 0.9733333333333334, 0.9616666666666667, 0.975, 0.9683333333333334, 0.9633333333333334, 0.9733333333333334, 0.9683333333333334, 0.9716666666666667, 0.975, 0.9666666666666667, 0.975, 0.9766666666666667, 0.975, 0.97, 0.975, 0.975, 0.975, 0.9733333333333334, 0.975, 0.98, 0.975, 0.9733333333333334, 0.9783333333333334, 0.9833333333333333, 0.9733333333333334, 0.97, 0.975, 0.9733333333333334, 0.975, 0.9716666666666667, 0.9766666666666667, 0.9783333333333334, 0.975, 0.975, 0.9716666666666667, 0.9816666666666667, 0.98, 0.9766666666666667, 0.9733333333333334, 0.98, 0.9783333333333334, 0.9733333333333334, 0.9783333333333334, 0.975, 0.965, 0.9716666666666667, 0.98, 0.9816666666666667, 0.9716666666666667, 0.975, 0.9733333333333334, 0.98, 0.98, 0.98, 0.9816666666666667, 0.9733333333333334, 0.9783333333333334, 0.9783333333333334, 0.98, 0.9783333333333334, 0.9766666666666667, 0.975, 0.97, 0.98, 0.98, 0.9783333333333334, 0.975, 0.9816666666666667, 0.9783333333333334, 0.9766666666666667, 0.9733333333333334, 0.9783333333333334, 0.9816666666666667, 0.98, 0.98, 0.975, 0.98, 0.9783333333333334, 0.9733333333333334, 0.9833333333333333, 0.98, 0.9783333333333334, 0.9766666666666667, 0.9766666666666667, 0.9766666666666667, 0.9766666666666667, 0.9833333333333333, 0.975, 0.97, 0.9866666666666667, 0.9716666666666667, 0.9783333333333334, 0.9783333333333334, 0.98, 0.98, 0.9766666666666667, 0.985, 0.98, 0.9783333333333334, 0.9783333333333334, 0.98, 0.9783333333333334, 0.9866666666666667, 0.975, 0.9783333333333334, 0.9783333333333334, 0.9833333333333333, 0.98, 0.98, 0.9833333333333333, 0.975, 0.98, 0.98, 0.9833333333333333, 0.9816666666666667, 0.98, 0.9783333333333334, 0.9783333333333334, 0.9783333333333334, 0.9833333333333333, 0.9833333333333333, 0.9716666666666667, 0.98, 0.9716666666666667, 0.9683333333333334, 0.9733333333333334, 0.985, 0.98, 0.985, 0.9783333333333334, 0.98, 0.98, 0.9833333333333333, 0.985, 0.9766666666666667, 0.9816666666666667, 0.985, 0.9733333333333334, 0.9833333333333333, 0.9833333333333333, 0.9866666666666667, 0.9833333333333333, 0.9783333333333334, 0.9816666666666667, 0.9783333333333334, 0.9783333333333334, 0.9766666666666667, 0.9816666666666667, 0.9833333333333333, 0.98, 0.9783333333333334, 0.9766666666666667, 0.9783333333333334, 0.985, 0.9816666666666667, 0.9783333333333334, 0.975, 0.9833333333333333, 0.9866666666666667, 0.9733333333333334, 0.9866666666666667, 0.9766666666666667, 0.9783333333333334, 0.9833333333333333, 0.98, 0.9783333333333334, 0.9783333333333334, 0.9783333333333334, 0.9816666666666667, 0.98, 0.9833333333333333, 0.985, 0.9833333333333333, 0.985, 0.98, 0.9833333333333333, 0.9783333333333334, 0.9766666666666667, 0.9833333333333333, 0.9816666666666667, 0.9833333333333333, 0.9766666666666667, 0.9783333333333334, 0.98, 0.985, 0.9816666666666667, 0.975, 0.9816666666666667, 0.9833333333333333, 0.9816666666666667, 0.9783333333333334]

# %% [markdown]
# #Narysuj dane testowe z prawdopodobieństwem przewidywanym przez sieć neuronową

# %%
draw_result(X_test, Z)

# %% [markdown]
# # **Krzywa ROC**

# %%
from sklearn.metrics import plot_roc_curve, auc, roc_curve, roc_auc_score

fig=plt.figure(figsize=(7,7))

roc_disp = plot_roc_curve(clf, X_test, y_test)
plt.show()

#Print AUC
fpr, tpr, _ = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)
print("Area Under Curve AUC = ",roc_auc)

#simpler method
print("Area Under Curve AUC = ",roc_auc_score(y_test, clf.predict_proba(X_test)[:,1]))
# Out:
# Area Under Curve AUC =  0.9977528029894995
# Area Under Curve AUC =  0.9977528029894995

# %% [markdown]
# # Visualize NN

# %%
! wget https://raw.githubusercontent.com/jzliu-100/visualize-neural-network/master/VisualizeNN.py

import VisualizeNN as VisNN
'''
print(clf.hidden_layer_sizes[0])
print(clf.n_outputs_)
print(clf.coefs_[0].shape)
print(clf.coefs_[1].shape)
print(clf.coefs_[2].shape)
'''

NN = list(clf.hidden_layer_sizes)
NN.append(clf.n_outputs_)
NN.insert(0,clf.coefs_[0].shape[0])
network=VisNN.DrawNN(NN,clf.coefs_)
network.draw()
# Out:
# --2020-11-23 16:26:42--  https://raw.githubusercontent.com/jzliu-100/visualize-neural-network/master/VisualizeNN.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9495 (9.3K) [text/plain]
# Saving to: ‘VisualizeNN.py’
#
# VisualizeNN.py      100%[===================>]   9.27K  --.-KB/s    in 0s
#
# 2020-11-23 16:26:42 (40.6 MB/s) - ‘VisualizeNN.py’ saved [9495/9495]

# %% [markdown]
# # To samo z użyciem drzew decyzyjnych BDT

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

#Drzewo decyzyjne
#clf = DecisionTreeClassifier(max_depth=5)

# Wzmocnione drzewo decyzyjne BDT
clf = AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME", n_estimators=200)


print(clf.fit(X_train, y_train))

# get score
score = clf.score(X_test, y_test)
print("Score = ",score)

# get prediction
Z = clf.predict_proba(X_test)[:,1] # returns probability 
print(Z)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#                    base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                          class_weight=None,
#                                                          criterion='gini',
#                                                          max_depth=1,
#                                                          max_features=None,
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
#                                                          min_impurity_split=None,
#                                                          min_samples_leaf=1,
#                                                          min_samples_split=2,
#                                                          min_weight_fraction_leaf=0.0,
#                                                          presort='deprecated',
#                                                          random_state=None,
#                                                          splitter='best'),
#                    learning_rate=1.0, n_estimators=200, random_state=None)
# Score =  0.922
# [0.49443497 0.42943996 0.49443497 ... 0.48823861 0.49443497 0.40642739]

# %%
draw_result(X_test,Z)

# %% [markdown]
# # **Krzywa ROC**

# %%
from sklearn.metrics import plot_roc_curve, auc, roc_curve, roc_auc_score

fig=plt.figure(figsize=(7,7))

roc_disp = plot_roc_curve(clf, X_test, y_test)
plt.show()

#Print AUC
fpr, tpr, _ = roc_curve(y_test, clf.predict_proba(X_test)[:,1])
roc_auc = auc(fpr, tpr)
print("Area Under Curve AUC = ",roc_auc)

#simpler method
print("Area Under Curve AUC = ",roc_auc_score(y_test, clf.predict_proba(X_test)[:,1]))
# Out:
# Area Under Curve AUC =  0.974476260269063
# Area Under Curve AUC =  0.974476260269063
